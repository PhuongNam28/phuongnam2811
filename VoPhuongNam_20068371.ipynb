# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd

# %%
df=pd.read_csv("orginal_sales_data_edit.csv",encoding="utf-8",header=0,delimiter=',')

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
cred=credentials.Certificate("./iuh-20068371-69927-firebase-adminsdk-x1k69-8e20e03d7e.json")
app=firebase_admin.initialize_app(cred)

# %%
dbFireStore=firestore.client()

# %%
for item in df.to_dict(orient='records'):
    doc_ref = dbFireStore.collection("tbl-20068371").document()
    doc_ref.set(item)

# %%
queryResults = list(dbFireStore.collection(u'tbl-20068371').stream())
listQueryResult = list(map(lambda x : x.to_dict(), queryResults))
df = pd.DataFrame(listQueryResult)
df
# Out:
#      TERRITORY  ORDERLINENUMBER SUBCATEGORY           CITY   STATUS  \
# 0          NaN               10   Bookshelf         Nashua  Shipped
# 1         EMEA                1       Ruler          Cowes  Shipped
# 2          NaN                1         Pen      Vancouver  Shipped
# 3          NaN                7      Eraser            NYC  Shipped
# 4          NaN               11         Pen       Pasadena  Shipped
# ...        ...              ...         ...            ...      ...
# 2818      EMEA                2   Bookshelf         Gensve  Shipped
# 2819      EMEA                4      Eraser        Bergamo  Shipped
# 2820       NaN                4        Lamp  San Francisco  Shipped
# 2821      EMEA                6       Table          Paris  Shipped
# 2822       NaN                7   Bookshelf     San Rafael  Shipped
#
#                    ADDRESSLINE1 ADDRESSLINE2  YEAR_ID CONTACTLASTNAME  \
# 0      2304 Long Airport Avenue          NaN     2004           Young
# ...

# %%
queryResults1 = list(dbFireStore.collection(u'tbl-20068371').where(u'COUNTRY', u'==', 'USA').stream())
listQueryResult1 = list(map(lambda x : x.to_dict(), queryResults1))
df1 = pd.DataFrame(listQueryResult1)
df1
# Out:
#       TERRITORY SUBCATEGORY  ORDERLINENUMBER           CITY   STATUS  \
# 0           NaN   Bookshelf               10         Nashua  Shipped
# 1           NaN      Eraser                7            NYC  Shipped
# 2           NaN         Pen               11       Pasadena  Shipped
# 3           NaN      Laptop                7         Boston  On Hold
# 4           NaN      Laptop                4    New Bedford  Shipped
# ...         ...         ...              ...            ...      ...
# 999         NaN   Bookshelf                4      Las Vegas  Shipped
# 1000        NaN   Bookshelf                8    Bridgewater  Shipped
# 1001        NaN       Ruler                9   White Plains  Shipped
# 1002        NaN        Lamp                4  San Francisco  Shipped
# 1003        NaN   Bookshelf                7     San Rafael  Shipped
#
#                    ADDRESSLINE1 ADDRESSLINE2  YEAR_ID CONTACTLASTNAME COUNTRY  \
# ...
